# %% [markdown]
# ### Load Gensim Library

# %%
# !pip install gensim --quiet

# %%
import gensim

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %% [markdown]
# ### Load Text Data
#
# Data can be downloaded from https://www.kaggle.com/c/word2vec-nlp-tutorial/data

# %%
#This is needed only if you have uploaded data to Google drive
from google.colab import drive
drive.mount('/gdrive')

# %%
import pandas as pd

#change file path to point to where you have stored the zip file.
df = pd.read_csv('/gdrive/My Drive/AI-ML/unlabeledTrainData.tsv.zip', header=0, delimiter="\t", quoting=3)

# %%
print('Number of examples in Dataset: ', df.shape)
df.head()
# Out:
# Number of examples in Dataset:  (50000, 2)
#           id                                             review
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...

# %%
df.loc[0, 'review']
# Out:
# '"Watching Time Chasers, it obvious that it was made by a bunch of friends. Maybe they were sitting around one day in film school and said, \\"Hey, let\'s pool our money together and make a really bad movie!\\" Or something like that. What ever they said, they still ended up making a really bad movie--dull story, bad script, lame acting, poor cinematography, bottom of the barrel stock music, etc. All corners were cut, except the one that would have prevented this film\'s release. Life\'s like that."'

# %% [markdown]
# ### Function to Clean up data

# %%
import re, string

def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)
  except:
    return ""

# %% [markdown]
# ### Clean the Data using routine above

# %%
df['clean_review'] = df['review'].apply(clean_str)
df.head()
# Out:
#           id  ...                                       clean_review
# 0   "9999_0"  ...  watching time chasers it obvious that it was m...
# 1  "45057_0"  ...  i saw this film about years ago and remember i...
# 2  "15561_0"  ...  minor spoilers br br in new york joan barnard ...
# 3   "7161_0"  ...  i went to see this film with a great deal of e...
# 4  "43971_0"  ...  yes i agree with everyone on this site this mo...
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Convert Review to a Word List

# %%
#List to hold all words in each review
documents = []

#Iterate over each review
for doc in df['clean_review']:
    documents.append(doc.split(' '))

# %%
print(len(documents))
# Out:
# 50000

# %%
print(documents[0])
# Out:
# ['watching', 'time', 'chasers', 'it', 'obvious', 'that', 'it', 'was', 'made', 'by', 'a', 'bunch', 'of', 'friends', 'maybe', 'they', 'were', 'sitting', 'around', 'one', 'day', 'in', 'film', 'school', 'and', 'said', 'hey', 'let', 's', 'pool', 'our', 'money', 'together', 'and', 'make', 'a', 'really', 'bad', 'movie', 'or', 'something', 'like', 'that', 'what', 'ever', 'they', 'said', 'they', 'still', 'ended', 'up', 'making', 'a', 'really', 'bad', 'movie', 'dull', 'story', 'bad', 'script', 'lame', 'acting', 'poor', 'cinematography', 'bottom', 'of', 'the', 'barrel', 'stock', 'music', 'etc', 'all', 'corners', 'were', 'cut', 'except', 'the', 'one', 'that', 'would', 'have', 'prevented', 'this', 'film', 's', 'release', 'life', 's', 'like', 'that']

# %% [markdown]
# ### Build the Model

# %%
#Build the model
model = gensim.models.Word2Vec(documents, #Word list
                               min_count=10, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPU Cores
                               size=50,  #Embedding size
                               window=5, #Neighbours on the left and right
                               iter=10   #Number of iterations over the text corpus
                              )
# Out:
# 2021-01-17 08:11:51,633 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2021-01-17 08:11:51,636 : INFO : collecting all words and their counts
# 2021-01-17 08:11:51,638 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-01-17 08:11:52,148 : INFO : PROGRESS: at sentence #10000, processed 2399440 words, keeping 51654 word types
# 2021-01-17 08:11:52,664 : INFO : PROGRESS: at sentence #20000, processed 4835846 words, keeping 69077 word types
# 2021-01-17 08:11:53,175 : INFO : PROGRESS: at sentence #30000, processed 7267977 words, keeping 81515 word types
# 2021-01-17 08:11:53,692 : INFO : PROGRESS: at sentence #40000, processed 9669772 words, keeping 91685 word types
# 2021-01-17 08:11:54,207 : INFO : collected 100479 word types from a corpus of 12084660 raw words and 50000 sentences
# 2021-01-17 08:11:54,209 : INFO : Loading a fresh vocabulary
# 2021-01-17 08:11:54,630 : INFO : effective_min_count=10 retains 28322 unique words (28% of original 100479, drops 72157)
# 2021-01-17 08:11:54,631 : INFO : effective_min_count=10 leaves 11910457 word corpus (98% of original 12084660, drops 174203)
# 2021-01-17 08:11:54,727 : INFO : deleting the raw counts dictionary of 100479 items
# 2021-01-17 08:11:54,731 : INFO : sample=0.001 downsamples 49 most-common words
# 2021-01-17 08:11:54,731 : INFO : downsampling leaves estimated 8817283 word corpus (74.0% of prior 11910457)
# 2021-01-17 08:11:54,843 : INFO : estimated required memory for 28322 words and 50 dimensions: 25489800 bytes
# 2021-01-17 08:11:54,848 : INFO : resetting layer weights
# 2021-01-17 08:12:00,431 : INFO : training model with 4 workers on 28322 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2021-01-17 08:12:01,460 : INFO : EPOCH 1 - PROGRESS: at 5.38% examples, 461802 words/s, in_qsize 4, out_qsize 3
# 2021-01-17 08:12:02,465 : INFO : EPOCH 1 - PROGRESS: at 11.07% examples, 477936 words/s, in_qsize 8, out_qsize 0
# 2021-01-17 08:12:03,484 : INFO : EPOCH 1 - PROGRESS: at 16.67% examples, 478414 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:12:04,487 : INFO : EPOCH 1 - PROGRESS: at 22.22% examples, 479650 words/s, in_qsize 6, out_qsize 1
# 2021-01-17 08:12:05,519 : INFO : EPOCH 1 - PROGRESS: at 27.74% examples, 478780 words/s, in_qsize 7, out_qsize 1
# 2021-01-17 08:12:06,527 : INFO : EPOCH 1 - PROGRESS: at 33.30% examples, 480304 words/s, in_qsize 6, out_qsize 1
# 2021-01-17 08:12:07,540 : INFO : EPOCH 1 - PROGRESS: at 38.88% examples, 482290 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:12:08,552 : INFO : EPOCH 1 - PROGRESS: at 44.27% examples, 481228 words/s, in_qsize 6, out_qsize 1
# 2021-01-17 08:12:09,574 : INFO : EPOCH 1 - PROGRESS: at 50.01% examples, 483114 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08
words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:37,419 : INFO : EPOCH 9 - PROGRESS: at 61.42% examples, 483514 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:38,431 : INFO : EPOCH 9 - PROGRESS: at 66.62% examples, 481538 words/s, in_qsize 6, out_qsize 1
# 2021-01-17 08:14:39,433 : INFO : EPOCH 9 - PROGRESS: at 72.25% examples, 482006 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:40,438 : INFO : EPOCH 9 - PROGRESS: at 77.75% examples, 482225 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:41,466 : INFO : EPOCH 9 - PROGRESS: at 83.43% examples, 482423 words/s, in_qsize 6, out_qsize 3
# 2021-01-17 08:14:42,485 : INFO : EPOCH 9 - PROGRESS: at 89.15% examples, 482281 words/s, in_qsize 6, out_qsize 1
# 2021-01-17 08:14:43,516 : INFO : EPOCH 9 - PROGRESS: at 94.76% examples, 482630 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:44,397 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-17 08:14:44,404 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-17 08:14:44,413 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-17 08:14:44,425 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-17 08:14:44,426 : INFO : EPOCH - 9 : training on 12084660 raw words (8816839 effective words) took 18.2s, 483646 effective words/s
# 2021-01-17 08:14:45,436 : INFO : EPOCH 10 - PROGRESS: at 5.38% examples, 470307 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:46,455 : INFO : EPOCH 10 - PROGRESS: at 10.99% examples, 475264 words/s, in_qsize 6, out_qsize 1
# 2021-01-17 08:14:47,481 : INFO : EPOCH 10 - PROGRESS: at 16.76% examples, 480476 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:48,515 : INFO : EPOCH 10 - PROGRESS: at 22.55% examples, 482749 words/s, in_qsize 8, out_qsize 1
# 2021-01-17 08:14:49,524 : INFO : EPOCH 10 - PROGRESS: at 28.13% examples, 484300 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:50,524 : INFO : EPOCH 10 - PROGRESS: at 33.69% examples, 485829 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:51,533 : INFO : EPOCH 10 - PROGRESS: at 39.18% examples, 486277 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:52,548 : INFO : EPOCH 10 - PROGRESS: at 44.65% examples, 485428 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:53,556 : INFO : EPOCH 10 - PROGRESS: at 50.02% examples, 483714 words/s, in_qsize 4, out_qsize 3
# 2021-01-17 08:14:54,578 : INFO : EPOCH 10 - PROGRESS: at 55.78% examples, 485272 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:55,588 : INFO : EPOCH 10 - PROGRESS: at 61.26% examples, 485170 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:56,593 : INFO : EPOCH 10 - PROGRESS: at 66.71% examples, 485038 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:57,601 : INFO : EPOCH 10 - PROGRESS: at 72.49% examples, 486050 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:58,614 : INFO : EPOCH 10 - PROGRESS: at 77.91% examples, 485393 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:14:59,634 : INFO : EPOCH 10 - PROGRESS: at 83.69% examples, 485580 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:15:00,661 : INFO : EPOCH 10 - PROGRESS: at 89.33% examples, 485168 words/s, in_qsize 7, out_qsize 1
# 2021-01-17 08:15:01,686 : INFO : EPOCH 10 - PROGRESS: at 94.92% examples, 485130 words/s, in_qsize 7, out_qsize 0
# 2021-01-17 08:15:02,550 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-17 08:15:02,565 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-17 08:15:02,570 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-17 08:15:02,571 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-17 08:15:02,573 : INFO : EPOCH - 10 : training on 12084660 raw words (8816118 effective words) took 18.1s, 485955 effective words/s
# 2021-01-17 08:15:02,578 : INFO : training on a 120846600 raw words (88173450 effective words) took 182.1s, 484083 effective words/s

# %%
#documents[0]

# %% [markdown]
# # Exploring the model

# %% [markdown]
# ### How many words in the model

# %%
#Model size
model.wv.vectors.shape
# Out:
# (28322, 50)

# %%
# Vocablury of the model
model.wv.vocab
# Out:
# {'watching': <gensim.models.keyedvectors.Vocab at 0x7f90096aca20>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f90096aca90>,
#  'chasers': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b470>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b518>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b588>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b5c0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b5f8>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b630>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b668>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b6a0>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b6d8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b710>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b748>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b780>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b7b8>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b7f0>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b828>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b860>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b898>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f8fc220beb8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f8fc220bf60>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f8fc220bef0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b400>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f8fc220b3c8>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f8fc220bdd8>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7f8fc220bd30>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f8fc220be10>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c64e0>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6518>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6550>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6588>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c65c0>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6630>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c65f8>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6668>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c66a0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c66d8>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6710>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6748>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6780>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c63c8>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6320>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6358>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c67b8>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6860>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c68d0>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6908>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6940>,
#  'lame': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6978>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c69b0>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c69e8>,
#  'cinematography': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6898>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c67f0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6828>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6a20>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6a58>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6ba8>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6be0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6c18>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6c50>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6c88>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6cc0>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6cf8>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6d30>,
#  'prevented': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6d68>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6da0>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6dd8>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6e10>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6e48>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6e80>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6eb8>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6ef0>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6f28>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6f60>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6f98>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6fd0>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6a90>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6ac8>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6b38>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6b70>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6b00>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9048>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9080>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e90b8>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e90f0>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9128>,
#  'breaks': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9160>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9198>,
#  'nurses': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e91d0>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9208>,
#  'rapes': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9240>,
#  'tortures': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9278>,
#  'kills': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e92b0>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e92e8>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9320>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9358>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9390>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e93c8>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9400>,
#  'saves': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9438>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9470>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e94a8>,
#  'shocking': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e94e0>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9518>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9550>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9588>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e95c0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e95f8>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9630>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9668>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e96a0>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e96d8>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9710>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9748>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9780>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e97b8>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e97f0>,
#  'obscene': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9828>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9860>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9898>,
#  'spoilers': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e98d0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9908>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9940>,
#  'joan': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9978>,
#  'barnard': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e99b0>,
#  'elvire': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e99e8>,
#  'audrey': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9a20>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9a58>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9a90>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9ac8>,
#  'arthur': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9b00>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9b38>,
#  'saxon': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9b70>,
#  'mysteriously': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9ba8>,
#  'murdered': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9be0>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9c18>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9c50>,
#  'searching': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9c88>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9cc0>,
#  'etruscan': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9cf8>,
#  'tomb': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9d30>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9d68>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9da0>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9dd8>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9e10>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9e48>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9e80>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9eb8>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9ef0>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9f28>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9f60>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9f98>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7f8fc21e9fd0>,
#  'visions': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed048>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed080>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed0b8>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed0f0>,
#  'maggots': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed128>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed160>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed198>,
#  'shootings': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed1d0>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed208>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed240>,
#  'realizes': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed278>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed2b0>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed2e8>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed320>,
#  'dealer': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed358>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed390>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed3c8>,
#  'drugs': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed400>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed438>,
#  'detective': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed470>,
#  'narcotic': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed4a8>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed4e0>,
#  'ends': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed518>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed550>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed588>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed5c0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed5f8>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed630>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed668>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed6a0>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed6d8>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed710>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed748>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed780>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed7b8>,
#  'displeasure': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed7f0>,
#  'wasting': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed828>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed860>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed898>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed8d0>,
#  'absurd': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed908>,
#  'mixing': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed940>,
#  'thriller': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed978>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed9b0>,
#  'supernatural': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ed9e8>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x7f8fc21eda20>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f8fc21eda58>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7f8fc21eda90>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edac8>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edb00>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edb38>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edb70>,
#  'highlighting': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edba8>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edbe0>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edc18>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edc50>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edc88>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edcc0>,
#  'credits': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edcf8>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edd30>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edd68>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edda0>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7f8fc21eddd8>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ede10>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ede48>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x7f8fc21ede80>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edeb8>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edef0>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edf28>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edf60>,
#  'direction': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edf98>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x7f8fc220be48>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7f8fc220bf28>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7f8fc220bf98>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f8fc220bfd0>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6080>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6048>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c60b8>,
#  'desire': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6160>,
#  'curiosity': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6128>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6198>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6240>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c62b0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6278>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c61d0>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6208>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c62e8>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6390>,
#  'navigate': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6400>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6438>,
#  'gym': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c60f0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c64a8>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f8fc21c6470>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7f8fc21edfd0>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1048>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1080>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f10b8>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f10f0>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1128>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1160>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1198>,
#  'mist': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f11d0>,
#  'rio': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1208>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1240>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1278>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f12b0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f12e8>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1320>,
#  'excitement': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1358>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1390>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f13c8>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1400>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1438>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1470>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f14a8>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f14e0>,
#  'stinks': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1518>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1550>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1588>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f15c0>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f15f8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1630>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1668>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f16a0>,
#  'walked': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f16d8>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1710>,
#  'pub': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1748>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1780>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f17b8>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f17f0>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1828>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1860>,
#  'balcony': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1898>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f18d0>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1908>,
#  'helicopter': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1940>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1978>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f19b0>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f19e8>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1a20>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1a58>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1a90>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1ac8>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1b00>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1b38>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1b70>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1ba8>,
#  'reporters': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1be0>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1c18>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1c50>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1c88>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1cc0>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1cf8>,
#  'jumping': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1d30>,
#  'encouraging': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1d68>,
#  'copy': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1da0>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1dd8>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1e10>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1e48>,
#  'circumstances': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1e80>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1eb8>,
#  'broadcasts': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1ef0>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1f28>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1f60>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1f98>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f1fd0>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5048>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5080>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f50b8>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f50f0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5128>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5160>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5198>,
#  'microphone': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f51d0>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5208>,
#  'transmitter': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5240>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5278>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f52b0>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f52e8>,
#  'utterly': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5320>,
#  'derivative': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5358>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5390>,
#  'existent': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f53c8>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5400>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5438>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5470>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f54a8>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f54e0>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5518>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5550>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5588>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f55c0>,
#  'compares': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f55f8>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5630>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5668>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f56a0>,
#  'describes': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f56d8>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5710>,
#  'packaging': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5748>,
#  'intentionally': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5780>,
#  'misleading': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f57b8>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f57f0>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5828>,
#  'describe': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5860>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5898>,
#  'retitled': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f58d0>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5908>,
#  'goofy': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5940>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5978>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f59b0>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f59e8>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5a20>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5a58>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5a90>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5ac8>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5b00>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5b38>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5b70>,
#  'locate': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5ba8>,
#  'rodney': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5be0>,
#  'dangerfield': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5c18>,
#  'comedians': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5c50>,
#  'hbo': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5c88>,
#  'featured': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5cc0>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5cf8>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5d30>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5d68>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5da0>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5dd8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5e10>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5e48>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5e80>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5eb8>,
#  'carrey': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5ef0>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5f28>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5f60>,
#  'annoying': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5f98>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f5fd0>,
#  'lacking': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9048>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9080>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f90b8>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f90f0>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9128>,
#  'comedian': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9160>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9198>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f91d0>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9208>,
#  'janet': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9240>,
#  'talented': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9278>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f92b0>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f92e8>,
#  'beware': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9320>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9358>,
#  'advertising': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9390>,
#  'jennifer': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f93c8>,
#  'ehle': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9400>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9438>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9470>,
#  'prejudice': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f94a8>,
#  'jeremy': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f94e0>,
#  'northam': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9518>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9550>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9588>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f95c0>,
#  'actors': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f95f8>,
#  'caliber': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9630>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9668>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f96a0>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f96d8>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9710>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9748>,
#  'sequences': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9780>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f97b8>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f97f0>,
#  'eager': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9828>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9860>,
#  'disappointment': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9898>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f98d0>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9908>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9940>,
#  'flick': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9978>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f99b0>,
#  'scenes': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f99e8>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9a20>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9a58>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9a90>,
#  'tenderness': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9ac8>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9b00>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9b38>,
#  'consisted': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9b70>,
#  'hackneyed': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9ba8>,
#  'unsubtle': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9be0>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9c18>,
#  'cinematic': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9c50>,
#  'lust': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9c88>,
#  'voracious': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9cc0>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9cf8>,
#  'mouthed': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9d30>,
#  'kissing': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9d68>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9da0>,
#  'porn': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9dd8>,
#  'humping': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9e10>,
#  'entertaining': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9e48>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9e80>,
#  'originality': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9eb8>,
#  'tasteless': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9ef0>,
#  'awful': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9f28>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9f60>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9f98>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x7f8fc21f9fd0>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc048>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc080>,
#  'romance': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc0b8>,
#  'effeminate': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc0f0>,
#  'appearance': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc128>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc160>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc198>,
#  'aren': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc1d0>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc208>,
#  'masculine': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc240>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc278>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc2b0>,
#  'hollywood': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc2e8>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc320>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc358>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc390>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc3c8>,
#  'imaginative': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc400>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc438>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc470>,
#  'amy': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc4a8>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc4e0>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc518>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc550>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc588>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc5c0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc5f8>,
#  'publisher': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc630>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc668>,
#  'guiding': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc6a0>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc6d8>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc710>,
#  'tour': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc748>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc780>,
#  'susan': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc7b8>,
#  'sarandon': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc7f0>,
#  'plays': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc828>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc860>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc898>,
#  'sadistic': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc8d0>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc908>,
#  'billy': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc940>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc978>,
#  'thorton': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc9b0>,
#  'chubby': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fc9e8>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fca20>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fca58>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fca90>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcac8>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcb00>,
#  'actress': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcb38>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcb70>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcba8>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcbe0>,
#  'gown': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcc18>,
#  'wears': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcc50>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcc88>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fccc0>,
#  'festival': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fccf8>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcd30>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcd68>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcda0>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcdd8>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fce10>,
#  'stale': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fce48>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fce80>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fceb8>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcef0>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcf28>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcf60>,
#  'adopts': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcf98>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x7f8fc21fcfd0>,
#  'contradicts': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f048>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f080>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f0b8>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f0f0>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f128>,
#  'erase': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f160>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f198>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f1d0>,
#  'carrying': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f208>,
#  'employees': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f240>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f278>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f2b0>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f2e8>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f320>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f358>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f390>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f3c8>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f400>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f438>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f470>,
#  'northwest': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f4a8>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f4e0>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f518>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f550>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f588>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f5c0>,
#  'harlan': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f5f8>,
#  'knowles': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f630>,
#  'lance': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f668>,
#  'henriksen': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f6a0>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f6d8>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f710>,
#  'ragtag': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f748>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f780>,
#  'execute': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f7b8>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f7f0>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f828>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f860>,
#  'oy': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f898>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f8d0>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f908>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f940>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f978>,
#  'genre': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f9b0>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7f8fc217f9e8>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fa20>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fa58>,
#  'suffers': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fa90>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fac8>,
#  'flaws': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fb00>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fb38>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fb70>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fba8>,
#  'jonas': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fbe0>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fc18>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fc50>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fc88>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fcc0>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fcf8>,
#  'aka': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fd30>,
#  'sasquatch': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fd68>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fda0>,
#  'editing': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fdd8>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fe10>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fe48>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fe80>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7f8fc217feb8>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x7f8fc217fef0>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x7f8fc217ff28>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7f8fc217ff60>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f8fc217ff98>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f8fc217ffd0>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183048>,
#  'improvise': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183080>,
#  'sequiturs': <gensim.models.keyedvectors.Vocab at 0x7f8fc21830b8>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x7f8fc21830f0>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183128>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183160>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183198>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x7f8fc21831d0>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183208>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183240>,
#  'crash': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183278>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7f8fc21832b0>,
#  'crib': <gensim.models.keyedvectors.Vocab at 0x7f8fc21832e8>,
#  'blair': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183320>,
#  'witch': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183358>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183390>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x7f8fc21833c8>,
#  'monster': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183400>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183438>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183470>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x7f8fc21834a8>,
#  'exposition': <gensim.models.keyedvectors.Vocab at 0x7f8fc21834e0>,
#  'dialogue': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183518>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183550>,
#  'subtler': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183588>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f8fc21835c0>,
#  'saccharine': <gensim.models.keyedvectors.Vocab at 0x7f8fc21835f8>,
#  'subtexts': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183630>,
#  'costume': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183668>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f8fc21836a0>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f8fc21836d8>,
#  'sufficient': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183710>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183748>,
#  'mixture': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183780>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7f8fc21837b8>,
#  'trudging': <gensim.models.keyedvectors.Vocab at 0x7f8fc21837f0>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183828>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183860>,
#  'chris': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183898>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x7f8fc21838d0>,
#  'stereotype': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183908>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183940>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183978>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f8fc21839b0>,
#  'exploring': <gensim.models.keyedvectors.Vocab at 0x7f8fc21839e8>,
#  'relationships': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183a20>,
#  'lair': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183a58>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183a90>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183ac8>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183b00>,
#  'specifically': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183b38>,
#  'corpse': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183b70>,
#  'decorations': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183ba8>,
#  'ala': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183be0>,
#  'primitive': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183c18>,
#  'jeepers': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183c50>,
#  'creepers': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183c88>,
#  'edited': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183cc0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183cf8>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183d30>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183d68>,
#  'frightening': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183da0>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183dd8>,
#  'missteps': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183e10>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183e48>,
#  'thinks': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183e80>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183eb8>,
#  'chop': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183ef0>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183f28>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183f60>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183f98>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f8fc2183fd0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186048>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186080>,
#  'screens': <gensim.models.keyedvectors.Vocab at 0x7f8fc21860b8>,
#  'snippets': <gensim.models.keyedvectors.Vocab at 0x7f8fc21860f0>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186128>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186160>,
#  'unspecified': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186198>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f8fc21861d0>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186208>,
#  'irrelevant': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186240>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186278>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f8fc21862b0>,
#  'occurring': <gensim.models.keyedvectors.Vocab at 0x7f8fc21862e8>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186320>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186358>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186390>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f8fc21863c8>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186400>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186438>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186470>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7f8fc21864a8>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f8fc21864e0>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186518>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186550>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186588>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f8fc21865c0>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7f8fc21865f8>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186630>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186668>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f8fc21866a0>,
#  'pointless': <gensim.models.keyedvectors.Vocab at 0x7f8fc21866d8>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186710>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186748>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186780>,
#  'justify': <gensim.models.keyedvectors.Vocab at 0x7f8fc21867b8>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7f8fc21867f0>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186828>,
#  'humanity': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186860>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186898>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x7f8fc21868d0>,
#  'mancini': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186908>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186940>,
#  'superfluous': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186978>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x7f8fc21869b0>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7f8fc21869e8>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186a20>,
#  'porno': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186a58>,
#  'motif': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186a90>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186ac8>,
#  'characters': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186b00>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186b38>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186b70>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186ba8>,
#  'stereotypes': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186be0>,
#  'asian': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186c18>,
#  'insists': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186c50>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186c88>,
#  'blurry': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186cc0>,
#  'cam': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186cf8>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186d30>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f8fc2186d68>,
# ...
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a160>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a198>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a1d0>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a208>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a240>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a278>,
#  'gritty': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a2b0>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a2e8>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a320>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a358>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a390>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a3c8>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a400>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a438>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a470>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a4a8>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a4e0>,
#  'directing': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a518>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a550>,
#  'manages': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a588>,
#  'sci': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a5c0>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a5f8>,
#  'cliches': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a630>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a668>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a6a0>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a6d8>,
#  'suspense': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a710>,
#  'landscape': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a748>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a780>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a7b8>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a7f0>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a828>,
#  'masterpiece': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a860>,
#  'fashioned': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a898>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a8d0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a908>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a940>,
#  'thoroughly': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a978>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a9b0>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x7f8fc218a9e8>,
#  'incredibly': <gensim.models.keyedvectors.Vocab at 0x7f8fc218aa20>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x7f8fc218aa58>,
#  'predictable': <gensim.models.keyedvectors.Vocab at 0x7f8fc218aa90>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7f8fc218aac8>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ab00>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ab38>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ab70>,
#  'gang': <gensim.models.keyedvectors.Vocab at 0x7f8fc218aba8>,
#  'rob': <gensim.models.keyedvectors.Vocab at 0x7f8fc218abe0>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ac18>,
#  'stations': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ac50>,
#  'rape': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ac88>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7f8fc218acc0>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7f8fc218acf8>,
#  'policeman': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ad30>,
#  'teenagers': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ad68>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ada0>,
#  'cliche': <gensim.models.keyedvectors.Vocab at 0x7f8fc218add8>,
#  'imaginable': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ae10>,
#  'hilarious': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ae48>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ae80>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x7f8fc218aeb8>,
#  'immortal': <gensim.models.keyedvectors.Vocab at 0x7f8fc218aef0>,
#  'jr': <gensim.models.keyedvectors.Vocab at 0x7f8fc218af28>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f8fc218af60>,
#  'laughs': <gensim.models.keyedvectors.Vocab at 0x7f8fc218af98>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x7f8fc218afd0>,
#  'ain': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e048>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e080>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e0b8>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e0f0>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e128>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e160>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e198>,
#  'sickened': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e1d0>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e208>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e240>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e278>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e2b0>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e2e8>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e320>,
#  'cnn': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e358>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e390>,
#  'abu': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e3c8>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e400>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e438>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e470>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e4a8>,
#  'intellectual': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e4e0>,
#  'stimulation': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e518>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e550>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e588>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e5c0>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e5f8>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e630>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e668>,
#  'guard': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e6a0>,
#  'reserves': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e6d8>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e710>,
#  'roughly': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e748>,
#  'abuses': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e780>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e7b8>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e7f0>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e828>,
#  'stepped': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e860>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e898>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e8d0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e908>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e940>,
#  'sarcastic': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e978>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e9b0>,
#  'commentary': <gensim.models.keyedvectors.Vocab at 0x7f8fc218e9e8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ea20>,
#  'enemy': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ea58>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ea90>,
#  'conflicts': <gensim.models.keyedvectors.Vocab at 0x7f8fc218eac8>,
#  'disaster': <gensim.models.keyedvectors.Vocab at 0x7f8fc218eb00>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x7f8fc218eb38>,
#  'humanitarian': <gensim.models.keyedvectors.Vocab at 0x7f8fc218eb70>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x7f8fc218eba8>,
#  'missions': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ebe0>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ec18>,
#  'indonesia': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ec50>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ec88>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ecc0>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ecf8>,
#  'overwhelmed': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ed30>,
#  'governments': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ed68>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x7f8fc218eda0>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x7f8fc218edd8>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ee10>,
#  'mocks': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ee48>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ee80>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f8fc218eeb8>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x7f8fc218eef0>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ef28>,
#  'villages': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ef60>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x7f8fc218ef98>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x7f8fc218efd0>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192048>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192080>,
#  'landing': <gensim.models.keyedvectors.Vocab at 0x7f8fc21920b8>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7f8fc21920f0>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192128>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192160>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192198>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7f8fc21921d0>,
#  'unscrupulous': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192208>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192240>,
#  'occupation': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192278>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x7f8fc21922b0>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x7f8fc21922e8>,
#  'minds': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192320>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192358>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192390>,
#  'mayhem': <gensim.models.keyedvectors.Vocab at 0x7f8fc21923c8>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192400>,
#  'disservice': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192438>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192470>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f8fc21924a8>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7f8fc21924e0>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192518>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192550>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192588>,
#  'entry': <gensim.models.keyedvectors.Vocab at 0x7f8fc21925c0>,
#  'personnel': <gensim.models.keyedvectors.Vocab at 0x7f8fc21925f8>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192630>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192668>,
#  'assuming': <gensim.models.keyedvectors.Vocab at 0x7f8fc21926a0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f8fc21926d8>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192710>,
#  'harm': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192748>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192780>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f8fc21927b8>,
#  'minimum': <gensim.models.keyedvectors.Vocab at 0x7f8fc21927f0>,
#  'wage': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192828>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192860>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192898>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x7f8fc21928d0>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192908>,
#  'nearby': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192940>,
#  'visitor': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192978>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7f8fc21929b0>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7f8fc21929e8>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192a20>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192a58>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192a90>,
#  'accepts': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192ac8>,
#  'lieu': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192b00>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192b38>,
#  'ged': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192b70>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192ba8>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192be0>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192c18>,
#  'undergraduate': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192c50>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192c88>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192cc0>,
#  'encouraged': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192cf8>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192d30>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192d68>,
#  'elfen': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192da0>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192dd8>,
#  'hasn': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192e10>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192e48>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192e80>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192eb8>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192ef0>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192f28>,
#  'violence': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192f60>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192f98>,
#  'haven': <gensim.models.keyedvectors.Vocab at 0x7f8fc2192fd0>,
#  'witnessed': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195048>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195080>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f8fc21950b8>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x7f8fc21950f0>,
#  'coherently': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195128>,
#  'pondering': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195160>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195198>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7f8fc21951d0>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195208>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195240>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195278>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x7f8fc21952b0>,
#  'anime': <gensim.models.keyedvectors.Vocab at 0x7f8fc21952e8>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195320>,
#  'shines': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195358>,
#  'narrative': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195390>,
#  'enthralled': <gensim.models.keyedvectors.Vocab at 0x7f8fc21953c8>,
#  'weaving': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195400>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195438>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195470>,
#  'gory': <gensim.models.keyedvectors.Vocab at 0x7f8fc21954a8>,
#  'encounter': <gensim.models.keyedvectors.Vocab at 0x7f8fc21954e0>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195518>,
#  'contrasting': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195550>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195588>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f8fc21955c0>,
#  'emotive': <gensim.models.keyedvectors.Vocab at 0x7f8fc21955f8>,
#  'bloodshed': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195630>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195668>,
#  'tears': <gensim.models.keyedvectors.Vocab at 0x7f8fc21956a0>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x7f8fc21956d8>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195710>,
#  'viewer': <gensim.models.keyedvectors.Vocab at 0x7f8fc2195748>,
#  ...}

# %% [markdown]
# ### Get an embedding for a word

# %%
model.wv['corners']
# Out:
# array([ 3.1250823e-01,  6.2953025e-01, -5.3930151e-01, -2.2235082e-01,
#         3.4406394e-02, -4.0225539e-02, -8.1245676e-03,  8.2767147e-01,
#         8.2249916e-01, -1.0689138e-05,  3.7456724e-01,  1.9993152e-01,
#        -8.2618707e-01,  4.6319214e-01,  2.0958680e-01,  2.1144494e-01,
#        -9.5636356e-01,  2.4882241e-01, -3.2372776e-01,  8.6474085e-01,
#        -1.8678010e-01, -2.1509089e-01, -1.1593798e+00,  4.8650544e-02,
#         3.8986304e-01, -3.6180177e-01,  7.2912753e-02, -6.1790681e-01,
#         1.4091675e+00, -5.7116175e-01, -4.4975586e-02, -3.3175018e-01,
#         1.3980058e+00, -9.6290588e-01, -5.3014588e-01,  8.0354804e-01,
#         5.3642583e-01, -2.7390775e-01, -3.5282066e-01, -5.4663581e-01,
#         2.9263896e-01,  1.0129520e+00, -2.7111357e-01, -5.3921586e-01,
#         2.5332987e-01,  1.5646270e-02,  1.1138320e-02, -8.5327888e-01,
#         4.8182723e-01, -3.2837741e-02], dtype=float32)

# %% [markdown]
# ### Finding Words which have similar meaning

# %%
model.wv.most_similar('great', topn=15)
# Out:
# 2021-01-17 08:23:38,819 : INFO : precomputing L2-norms of word weight vectors
# [('fantastic', 0.8950309157371521),
#  ('wonderful', 0.8747765421867371),
#  ('terrific', 0.8665562868118286),
#  ('fine', 0.8425877690315247),
#  ('good', 0.8256796598434448),
#  ('brilliant', 0.8110665082931519),
#  ('superb', 0.7785057425498962),
#  ('perfect', 0.7527344822883606),
#  ('nice', 0.7472909092903137),
#  ('amazing', 0.73293536901474),
#  ('marvelous', 0.730586051940918),
#  ('awesome', 0.72437584400177),
#  ('fabulous', 0.7235651612281799),
#  ('spectacular', 0.7229869365692139),
#  ('remarkable', 0.7209872007369995)]

# %% [markdown]
# ### Find the word which is not like others

# %%
model.doesnt_match("man woman child kitchen".split())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'kitchen'

# %% [markdown]
# ### Saving the model

# %%
model.save('word2vec-movie-50')
# Out:
# 2021-01-17 08:29:57,141 : INFO : saving Word2Vec object under word2vec-movie-50, separately None
# 2021-01-17 08:29:57,143 : INFO : not storing attribute vectors_norm
# 2021-01-17 08:29:57,145 : INFO : not storing attribute cum_table
# 2021-01-17 08:29:57,367 : INFO : saved word2vec-movie-50

# %%
# !ls -l
# Out:
# total 18536
# drwxr-xr-x 1 root root     4096 Jan  6 18:10 sample_data
# -rw-r--r-- 1 root root 18975625 Jan 17 08:29 word2vec-movie-50

# %%
#Load model from memory
model = gensim.models.Word2Vec.load('word2vec-movie-50')
# Out:
# 2021-01-17 08:30:03,112 : INFO : loading Word2Vec object from word2vec-movie-50
# 2021-01-17 08:30:03,273 : INFO : loading wv recursively from word2vec-movie-50.wv.* with mmap=None
# 2021-01-17 08:30:03,274 : INFO : setting ignored attribute vectors_norm to None
# 2021-01-17 08:30:03,275 : INFO : loading vocabulary recursively from word2vec-movie-50.vocabulary.* with mmap=None
# 2021-01-17 08:30:03,276 : INFO : loading trainables recursively from word2vec-movie-50.trainables.* with mmap=None
# 2021-01-17 08:30:03,276 : INFO : setting ignored attribute cum_table to None
# 2021-01-17 08:30:03,277 : INFO : loaded word2vec-movie-50

# %% [markdown]
# 1. Equation king + man = queen + ?
# 2. In this case there may not be enough data for this equation

# %%
model.most_similar(positive=['king','man'], negative=['queen'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2021-01-17 08:32:15,592 : INFO : precomputing L2-norms of word weight vectors
# [('soldier', 0.5844407677650452),
#  ('scientist', 0.5803942084312439),
#  ('marine', 0.5649991631507874),
#  ('buio', 0.5623047947883606),
#  ('master', 0.5462765693664551),
#  ('warlord', 0.5370714664459229),
#  ('seed', 0.5318151712417603),
#  ('cop', 0.5304993987083435),
#  ('filmmaker', 0.5286292433738708),
#  ('joker', 0.5281445384025574)]

# %%
model.wv['king'] + model.wv['man'] - model.wv['queen']
